# %% [markdown]
# <a href="https://colab.research.google.com/github/jpmazate90/HorarioGenetico/blob/master/HorarioInteligente_Version_Cromosoma.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install flask-ngrok
# Out:
# Requirement already satisfied: flask-ngrok in /usr/local/lib/python3.7/dist-packages (0.0.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from flask-ngrok) (2.23.0)
# Requirement already satisfied: Flask>=0.8 in /usr/local/lib/python3.7/dist-packages (from flask-ngrok) (1.1.2)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->flask-ngrok) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->flask-ngrok) (2020.12.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->flask-ngrok) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->flask-ngrok) (1.24.3)
# Requirement already satisfied: itsdangerous>=0.24 in /usr/local/lib/python3.7/dist-packages (from Flask>=0.8->flask-ngrok) (1.1.0)
# Requirement already satisfied: Jinja2>=2.10.1 in /usr/local/lib/python3.7/dist-packages (from Flask>=0.8->flask-ngrok) (2.11.3)
# Requirement already satisfied: click>=5.1 in /usr/local/lib/python3.7/dist-packages (from Flask>=0.8->flask-ngrok) (7.1.2)
# Requirement already satisfied: Werkzeug>=0.15 in /usr/local/lib/python3.7/dist-packages (from Flask>=0.8->flask-ngrok) (1.0.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2>=2.10.1->Flask>=0.8->flask-ngrok) (1.1.1)

# %%
class Docente:

  def __init__(self,carnet,nombre):
    self.carnet = carnet
    self.nombre = nombre

class Curso:
    def __init__(self,codigo,nombre,ciclo,seccion,carrera):
      self.codigo = codigo
      self.nombre = nombre
      self.ciclo = ciclo
      self.seccion = seccion
      self.carrera = carrera

class Salon:
   
    def __init__(self, paramNumeroSalon, paramCapacidad):
      self.numeroSalon = paramNumeroSalon
      self.capacidad = paramCapacidad

class Cromosoma:
  def __init__(self):
    self.lista = []
    self.porcentaje = 100

# %%
from google.colab import auth
auth.authenticate_user()
import gspread
from oauth2client.client import GoogleCredentials

gc = gspread.authorize(GoogleCredentials.get_application_default())

#Captura de datos
docentesWorksheet = gc.open_by_url('https://docs.google.com/spreadsheets/d/1x8im5OKNCfnfJ3IWCysxqlfX-rpL0fGKLasZV8roaWc/edit#gid=613333572').sheet1
salonesWorksheet = gc.open_by_url('https://docs.google.com/spreadsheets/d/19kLciSLwoqPUgMhwnaJkIMVVKaYFBw_exNLBW2-jmI4/edit#gid=1713769866').sheet1
cursosWorksheet = gc.open_by_url('https://docs.google.com/spreadsheets/d/1PQKKlGwJ3_ai6JITlMjBsOyEOOMzS9ig3ZOfArAPHZI/edit#gid=1737435044').sheet1

# get_all_values gives a list of docentesWorksheet.
docentes = docentesWorksheet.get_all_values()
listaDocentes=[]
del docentes[0]
for row in docentes:
  listaDocentes.append(Docente(row[1],row[2]))

# get_all_values gives a list of docentesWorksheet.
salones = salonesWorksheet.get_all_values()
listaSalones=[]
del salones[0]
for row in salones:
 listaSalones.append(Salon(row[1],row[2]))

# get_all_values gives a list of docentesWorksheet.
cursos = cursosWorksheet.get_all_values()
listaCursos=[]
del cursos[0]
for row in cursos:
  listaCursos.append(Curso(row[1],row[2],row[3],row[4],row[5]))

# Convert to a DataFrame and render.
import pandas as pd
import random
import numpy as np

CANTIDAD_PERIODOS = 6
CANTIDAD_CROMOSOMAS = 100
CANTIDAD_PENALIZACION_R1 = -5
CANTIDAD_PENALIZACION_R2 = -2.5


def crearCromosoma(listadoParaCromosoma):
  cromosoma= Cromosoma()
  for salon in listadoParaCromosoma:
    listado= []
    for periodo in range(CANTIDAD_PERIODOS):  
      listado.append(random.choice(listaCursos))  
    cromosoma.lista.append(listado)
  return cromosoma



def mostrarCromosoma(cromosomaa:Cromosoma):
  contador = 1
  print("Porcentaje de aceptacion del cromosoma: "+str(cromosomaa.porcentaje)+"%")
  for crom in cromosomaa.lista:
    print("-----salon "+str(contador)+"-------")
    for c in crom:
      print(" ###Curso### \n Ciclo: "+c.ciclo  + "\n Codigo: "+c.codigo+"\n Nombre: "+c.nombre+"\n Seccion: "+c.seccion+"\n Carrera: "+c.carrera)
    contador+=1
  
def crearPoblacionInicial():
  arregloCreadoPoblacion = []
  for i in range(CANTIDAD_CROMOSOMAS):
    arregloCreadoPoblacion.append(crearCromosoma(listaSalones))
  return arregloCreadoPoblacion

def mostrarPoblacionInicial(arregloPoblacion):
  contador = 1
  for crom in arregloPoblacion:
    print("*************CROMOSOMA #"+str(contador)+"*************")
    mostrarCromosoma(crom)
    contador +=1

#Funcion para seleccionar cormosomas

def seleccionarCromosomas(cromosomaa:Cromosoma):
  
  porcentajeCr = 0;
  numeroSalon = 1;
  
  for salon in cromosomaa.lista:
    contador = 0
    for c in salon:
      porcentajeCr += compararCromosomaR1(c,numeroSalon,contador,cromosomaa.lista)
      porcentajeCr += compararCromosomaR2(c,contador,salon,numeroSalon)
      contador+=1
    numeroSalon +=1  

  cromosomaa.porcentaje +=porcentajeCr

            

def compararCromosomaR1(cr:Curso,numeroSalonActual,posicionCurso, listadoSalonesCromosoma):
  porcentaje = 0
  numeroSalonLocal = 1
  for salon in listadoSalonesCromosoma:
    if numeroSalonLocal!=numeroSalonActual:
      contador = 0
      for curso in salon:
        if contador == posicionCurso:
          if cr.seccion == curso.seccion and cr.ciclo == curso.ciclo:
            print("Error R1: Salon: "+str(numeroSalonActual)+" Curso a comparar: "+cr.nombre,cr.seccion,cr.ciclo, ". Salon:"+ str(numeroSalonLocal)+" Curso con el que se comparo:"+curso.nombre,curso.seccion, curso.ciclo)
            porcentaje+=CANTIDAD_PENALIZACION_R1
        contador+=1
    numeroSalonLocal +=1
  return porcentaje;

def compararCromosomaR2(cr:Curso,posicionCurso, listadoCursos, numeroSalon):
  porcentaje = 0
  contador = 0
  for curso in listadoCursos:
    if contador != posicionCurso:
      if cr.seccion == curso.seccion and cr.ciclo == curso.ciclo and cr.codigo == curso.codigo and cr.carrera == curso.carrera: 
        print("Error R2: Salon: "+str(numeroSalon)+" Curso a comparar: "+cr.nombre,cr.seccion,cr.ciclo, ". Curso con el que se comparo:"+curso.nombre,curso.seccion, curso.ciclo)
        porcentaje+=CANTIDAD_PENALIZACION_R2
    contador+=1
  return porcentaje;


def seleccionarPoblacion(arregloPoblacion):
  contador = 0
  for crom in arregloPoblacion:
    print("*****CROMSOMA "+str(contador)+"****************")
    seleccionarCromosomas(crom)
    contador+=1



poblacionInicial= crearPoblacionInicial()
seleccionarPoblacion(poblacionInicial)
#mostrarPoblacionInicial(poblacionInicial)

# evaluarPoblacion()




#probando github



  


#.DataFrame.from_records(docentes)
#pd.DataFrame.from_records(salones)
#pd.DataFrame.from_records(cursos)


#print(listaCursos[0].nombre)
#Creacion de cromosoma

# 1. No se puede repetir el mismo curso del mismo semestre de la misma carrera en la misma posicion en mas de un salon
# 2. No se pueden repetir el mimso curso en un salon


# 3. Que een el mismo salon no se repita el mismo codigo con la misma seccion

# 4, que la mismo informacion no se repita en el mismo salon

# 5  no se repitra a la mimsa un curso del mismo ciclo

# 6 A la misma hora no se debe repetir un curso de la misma seccion 

# Dar el mismo curso con la msma secion en el mismo ciclo
# Out:
# *****CROMSOMA 0****************
# Error R2: Salon: 1 Curso a comparar: Matemática Aplicada 1 A 8 . Curso con el que se comparo:Matemática Aplicada 1 A 8
# Error R1: Salon: 1 Curso a comparar: ipc2 D 5 . Salon:2 Curso con el que se comparo:ipc2 D 5
# Error R1: Salon: 1 Curso a comparar: Fisica basica B 2 . Salon:2 Curso con el que se comparo:Tecnica Complementaria 1 B 2
# Error R2: Salon: 1 Curso a comparar: Matemática Aplicada 1 A 8 . Curso con el que se comparo:Matemática Aplicada 1 A 8
# Error R1: Salon: 1 Curso a comparar: Teoria de Sistemas 1 B 6 . Salon:3 Curso con el que se comparo:Compiladores 2 B 6
# Error R1: Salon: 2 Curso a comparar: ipc2 D 5 . Salon:1 Curso con el que se comparo:ipc2 D 5
# Error R1: Salon: 2 Curso a comparar: Tecnica Complementaria 1 B 2 . Salon:1 Curso con el que se comparo:Fisica basica B 2
# Error R2: Salon: 2 Curso a comparar: Tecnica Complementaria 1 B 2 . Curso con el que se comparo:Tecnica Complementaria 1 B 2
# Error R1: Salon: 2 Curso a comparar: Tecnica Complementaria 1 B 2 . Salon:4 Curso con el que se comparo:Fisica basica B 2
# Error R2: Salon: 2 Curso a comparar: Tecnica Complementaria 1 B 2 . Curso con el que se comparo:Tecnica Complementaria 1 B 2
# Error R2: Salon: 3 Curso a comparar: Compiladores 2 B 6 . Curso con el que se comparo:Compiladores 2 B 6
# Error R1: Salon: 3 Curso a comparar: Compiladores 2 B 6 . Salon:1 Curso con el que se comparo:Teoria de Sistemas 1 B 6
# Error R2: Salon: 3 Curso a comparar: Compiladores 2 B 6 . Curso con el que se comparo:Compiladores 2 B 6
# Error R1: Salon: 4 Curso a comparar: ipc1 C 4 . Salon:5 Curso con el que se comparo:ipc1 C 4
# Error R1: Salon: 4 Curso a comparar: Fisica basica B 2 . Salon:2 Curso con el que se comparo:Tecnica Complementaria 1 B 2
# Error R1: Salon: 4 Curso a comparar: Matemática Computo 1 A 3 . Salon:5 Curso con el que se comparo:IPC1 A 3
# Error R1: Salon: 5 Curso a comparar: ipc1 C 4 . Salon:4 Curso con el que se comparo:ipc1 C 4
# Error R2: Salon: 5 Curso a comparar: ipc1 C 4 . Curso con el que se comparo:ipc1 C 4
# Error R2: Salon: 5 Curso a comparar: ipc1 C 4 . Curso con el que se comparo:ipc1 C 4
# Error R1: Salon: 5 Curso a comparar: IPC1 A 3 . Salon:4 Curso con el que se comparo:Matemática Computo 1 A 3
# Error R2: Salon: 6 Curso a comparar: lenguajes E 4 . Curso con el que se comparo:lenguajes E 4
# Error R2: Salon: 6 Curso a comparar: Compiladores 2 B 6 . Curso con el que se comparo:Compiladores 2 B 6
# Error R2: Salon: 6 Curso a comparar: Compiladores 2 B 6 . Curso con el que se comparo:Compiladores 2 B 6
# Error R2: Salon: 6 Curso a comparar: lenguajes E 4 . Curso con el que se comparo:lenguajes E 4
# *****CROMSOMA 1****************
# Error R2: Salon: 1 Curso a comparar: Inteligencia Artificial A 9 . Curso con el que se comparo:Inteligencia Artificial A 9
# Error R2: Salon: 1 Curso a comparar: Inteligencia Artificial A 9 . Curso con el que se comparo:Inteligencia Artificial A 9
# Error R2: Salon: 1 Curso a comparar: Inteligencia Artificial A 9 . Curso con el que se comparo:Inteligencia Artificial A 9
# Error R2: Salon: 1 Curso a comparar: Inteligencia Artificial A 9 . Curso con el que se comparo:Inteligencia Artificial A 9
# Error R2: Salon: 1 Curso a comparar: Inteligencia Artificial A 9 . Curso con el que se comparo:Inteligencia Artificial A 9
# Error R2: Salon: 1 Curso a comparar: Inteligencia Artificial A 9 . Curso con el que se comparo:Inteligencia Artificial A 9
# Error R1: Salon: 1 Curso a comparar: Matematica basica 1 A 1 . Salon:3 Curso con el que se comparo:Inteligencia Artificial A 1
# Error R2: Salon: 1 Curso a comparar: Inteligencia Artificial A 9 . Curso con el que se comparo:Inteligencia Artificial A 9
# Error R2: Salon: 1 Curso a comparar: Inteligencia Artificial A 9 . Curso con el que se comparo:Inteligencia Artificial A 9
# Error R2: Salon: 1 Curso a comparar: Inteligencia Artificial A 9 . Curso con el que se comparo:Inteligencia Artificial A 9
# Error R2: Salon: 1 Curso a comparar: Inteligencia Artificial A 9 . Curso con el que se comparo:Inteligencia Artificial A 9
# Error R2: Salon: 1 Curso a comparar: Inteligencia Artificial A 9 . Curso con el que se comparo:Inteligencia Artificial A 9
# Error R2: Salon: 1 Curso a comparar: Inteligencia Artificial A 9 . Curso con el que se comparo:Inteligencia Artificial A 9
# Error R1: Salon: 2 Curso a comparar: Matemática Computo 1 A 3 . Salon:3 Curso con el que se comparo:Matemática Computo 1 A 3
# Error R1: Salon: 2 Curso a comparar: Compiladores 2 B 6 . Salon:5 Curso con el que se comparo:Compiladores 2 B 6
# Error R1: Salon: 3 Curso a comparar: Compiladores 1 D 1 . Salon:5 Curso con el que se comparo:Compiladores 1 D 1
# Error R1: Salon: 3 Curso a comparar: Inteligencia Artificial A 1 . Salon:1 Curso con el que se comparo:Matematica basica 1 A 1
# Error R1: Salon: 3 Curso a comparar: Matemática Computo 1 A 3 . Salon:2 Curso con el que se comparo:Matemática Computo 1 A 3
# Error R2: Salon: 3 Curso a comparar: Matemática Computo 1 A 3 . Curso con el que se comparo:Matemática Computo 1 A 3
# Error R2: Salon: 3 Curso a comparar: Matemática Computo 1 A 3 . Curso con el que se comparo:Matemática Computo 1 A 3
# Error R1: Salon: 4 Curso a comparar: Tecnica Complementaria 1 B 2 . Salon:6 Curso con el que se comparo:Fisica basica B 2
# Error R2: Salon: 4 Curso a comparar: Matematica basica 1 A 1 . Curso con el que se comparo:Matematica basica 1 A 1
# Error R2: Salon: 4 Curso a comparar: Matematica basica 1 A 1 . Curso con el que se comparo:Matematica basica 1 A 1
# Error R2: Salon: 5 Curso a comparar: Compiladores 1 D 1 . Curso con el que se comparo:Compiladores 1 D 1
# Error R1: Salon: 5 Curso a comparar: Compiladores 1 D 1 . Salon:3 Curso con el que se comparo:Compiladores 1 D 1
# Error R2: Salon: 5 Curso a comparar: Compiladores 1 D 1 . Curso con el que se comparo:Compiladores 1 D 1
# Error R1: Salon: 5 Curso a comparar: Compiladores 2 B 6 . Salon:2 Curso con el que se comparo:Compiladores 2 B 6
# Error R1: Salon: 6 Curso a comparar: Fisica basica B 2 . Salon:4 Curso con el que se comparo:Tecnica Complementaria 1 B 2
# Error R2: Salon: 6 Curso a comparar: Fisica basica B 2 . Curso con el que se comparo:Fisica basica B 2
# Error R2: Salon: 6 Curso a comparar: Fisica basica B 2 . Curso con el que se comparo:Fisica basica B 2
# *****CROMSOMA 2****************
# Error R2: Salon: 1 Curso a comparar: Inteligencia Artificial A 1 . Curso con el que se comparo:Inteligencia Artificial A 1
# Error R1: Salon: 1 Curso a comparar: ipc1 C 4 . Salon:6 Curso con el que se comparo:ipc1 C 4
# Error R1: Salon: 1 Curso a comparar: Compiladores 1 D 1 . Salon:5 Curso con el que se comparo:Compiladores 1 D 1
# Error R1: Salon: 1 Curso a comparar: IPC1 A 3 . Salon:6 Curso con el que se comparo:IPC1 A 3
# Error R2: Salon: 1 Curso a comparar: Inteligencia Artificial A 1 . Curso con el que se comparo:Inteligencia Artificial A 1
# Error R2: Salon: 2 Curso a comparar: Compiladores 1 D 1 . Curso con el que se comparo:Compiladores 1 D 1
# Error R2: Salon: 2 Curso a comparar: Compiladores 1 D 1 . Curso con el que se comparo:Compiladores 1 D 1
# Error R1: Salon: 4 Curso a comparar: Matemática Computo 1 A 3 . Salon:6 Curso con el que se comparo:IPC1 A 3
# Error R1: Salon: 5 Curso a comparar: Compiladores 1 D 1 . Salon:1 Curso con el que se comparo:Compiladores 1 D 1
# Error R1: Salon: 6 Curso a comparar: ipc1 C 4 . Salon:1 Curso con el que se comparo:ipc1 C 4
# Error R2: Salon: 6 Curso a comparar: ipc1 C 4 . Curso con el que se comparo:ipc1 C 4
# Error R1: Salon: 6 Curso a comparar: IPC1 A 3 . Salon:4 Curso con el que se comparo:Matemática Computo 1 A 3
# Error R2: Salon: 6 Curso a comparar: IPC1 A 3 . Curso con el que se comparo:IPC1 A 3
# Error R1: Salon: 6 Curso a comparar: IPC1 A 3 . Salon:1 Curso con el que se comparo:IPC1 A 3
# Error R2: Salon: 6 Curso a comparar: IPC1 A 3 . Curso con el que se comparo:IPC1 A 3
# Error R2: Salon: 6 Curso a comparar: ipc1 C 4 . Curso con el que se comparo:ipc1 C 4
# *****CROMSOMA 3****************
# Error R2: Salon: 1 Curso a comparar: Matemática Computo 1 A 3 . Curso con el que se comparo:Matemática Computo 1 A 3
# Error R2: Salon: 1 Curso a comparar: Matemática Computo 1 A 3 . Curso con el que se comparo:Matemática Computo 1 A 3
# Error R1: Salon: 1 Curso a comparar: Tecnica Complementaria 1 B 2 . Salon:3 Curso con el que se comparo:Fisica basica B 2
# Error R2: Salon: 1 Curso a comparar: Matemática Computo 1 A 3 . Curso con el que se comparo:Matemática Computo 1 A 3
# Error R2: Salon: 1 Curso a comparar: Matemática Computo 1 A 3 . Curso con el que se comparo:Matemática Computo 1 A 3
# Error R1: Salon: 1 Curso a comparar: Inteligencia Artificial A 1 . Salon:5 Curso con el que se comparo:Inteligencia Artificial A 1
# Error R2: Salon: 1 Curso a comparar: Matemática Computo 1 A 3 . Curso con el que se comparo:Matemática Computo 1 A 3
# Error R2: Salon: 1 Curso a comparar: Matemática Computo 1 A 3 . Curso con el que se comparo:Matemática Computo 1 A 3
# Error R2: Salon: 2 Curso a comparar: Fisica basica B 2 . Curso con el que se comparo:Fisica basica B 2
# Error R2: Salon: 2 Curso a comparar: Fisica basica B 2 . Curso con el que se comparo:Fisica basica B 2
# Error R1: Salon: 2 Curso a comparar: Matematica basica 1 A 1 . Salon:6 Curso con el que se comparo:Inteligencia Artificial A 1
# Error R1: Salon: 2 Curso a comparar: Tecnica Complementaria 1 B 2 . Salon:5 Curso con el que se comparo:Tecnica Complementaria 1 B 2
# Error R1: Salon: 2 Curso a comparar: Fisica basica B 2 . Salon:6 Curso con el que se comparo:Fisica basica B 2
# Error R2: Salon: 2 Curso a comparar: Fisica basica B 2 . Curso con el que se comparo:Fisica basica B 2
# Error R2: Salon: 2 Curso a comparar: Fisica basica B 2 . Curso con el que se comparo:Fisica basica B 2
# Error R1: Salon: 2 Curso a comparar: Fisica basica B 2 . Salon:3 Curso con el que se comparo:Tecnica Complementaria 1 B 2
# Error R2: Salon: 2 Curso a comparar: Fisica basica B 2 . Curso con el que se comparo:Fisica basica B 2
# Error R2: Salon: 2 Curso a comparar: Fisica basica B 2 . Curso con el que se comparo:Fisica basica B 2
# Error R1: Salon: 3 Curso a comparar: Fisica basica B 2 . Salon:1 Curso con el que se comparo:Tecnica Complementaria 1 B 2
# Error R1: Salon: 3 Curso a comparar: Teoria de Sistemas 1 B 6 . Salon:4 Curso con el que se comparo:Compiladores 2 B 6
# Error R2: Salon: 3 Curso a comparar: Teoria de Sistemas 1 B 6 . Curso con el que se comparo:Teoria de Sistemas 1 B 6
# Error R1: Salon: 3 Curso a comparar: Teoria de Sistemas 1 B 6 . Salon:5 Curso con el que se comparo:Compiladores 2 B 6
# Error R2: Salon: 3 Curso a comparar: Teoria de Sistemas 1 B 6 . Curso con el que se comparo:Teoria de Sistemas 1 B 6
# Error R1: Salon: 3 Curso a comparar: Tecnica Complementaria 1 B 2 . Salon:2 Curso con el que se comparo:Fisica basica B 2
# Error R1: Salon: 4 Curso a comparar: ipc2 D 5 . Salon:5 Curso con el que se comparo:ipc2 D 5
# Error R1: Salon: 4 Curso a comparar: Matemática Computo 1 A 3 . Salon:5 Curso con el que se comparo:IPC1 A 3
# Error R1: Salon: 4 Curso a comparar: Compiladores 1 D 1 . Salon:6 Curso con el que se comparo:Compiladores 1 D 1
# Error R1: Salon: 4 Curso a comparar: Compiladores 2 B 6 . Salon:3 Curso con el que se comparo:Teoria de Sistemas 1 B 6
# Error R1: Salon: 5 Curso a comparar: ipc2 D 5 . Salon:4 Curso con el que se comparo:ipc2 D 5
# Error R1: Salon: 5 Curso a comparar: IPC1 A 3 . Salon:4 Curso con el que se comparo:Matemática Computo 1 A 3
# Error R1: Salon: 5 Curso a comparar: Tecnica Complementaria 1 B 2 . Salon:2 Curso con el que se comparo:Tecnica Complementaria 1 B 2
# Error R1: Salon: 5 Curso a comparar: Inteligencia Artificial A 1 . Salon:1 Curso con el que se comparo:Inteligencia Artificial A 1
# Error R1: Salon: 5 Curso a comparar: Compiladores 2 B 6 . Salon:3 Curso con el que se comparo:Teoria de Sistemas 1 B 6
# Error R1: Salon: 6 Curso a comparar: Inteligencia Artificial A 1 . Salon:2 Curso con el que se comparo:Matematica basica 1 A 1
# Error R1: Salon: 6 Curso a comparar: Compiladores 1 D 1 . Salon:4 Curso con el que se comparo:Compiladores 1 D 1
# Error R1: Salon: 6 Curso a comparar: Fisica basica B 2 . Salon:2 Curso con el que se comparo:Fisica basica B 2
# *****CROMSOMA 4****************
# Error R1: Salon: 1 Curso a comparar: Inteligencia Artificial A 1 . Salon:4 Curso con el que se comparo:Inteligencia Artificial A 1
# Error R1: Salon: 1 Curso a comparar: Inteligencia Artificial A 9 . Salon:5 Curso con el que se comparo:Inteligencia Artificial A 9
# Error R2: Salon: 1 Curso a comparar: Inteligencia Artificial A 9 . Curso con el que se comparo:Inteligencia Artificial A 9
# Error R2: Salon: 1 Curso a comparar: Inteligencia Artificial A 9 . Curso con el que se comparo:Inteligencia Artificial A 9
# Error R1: Salon: 2 Curso a comparar: Teoria de Sistemas 1 B 6 . Salon:6 Curso con el que se comparo:Teoria de Sistemas 1 B 6
# Error R2: Salon: 2 Curso a comparar: Teoria de Sistemas 1 B 6 . Curso con el que se comparo:Teoria de Sistemas 1 B 6
# Error R2: Salon: 2 Curso a comparar: Teoria de Sistemas 1 B 6 . Curso con el que se comparo:Teoria de Sistemas 1 B 6
# Error R1: Salon: 3 Curso a comparar: Inteligencia Artificial A 9 . Salon:6 Curso con el que se comparo:Inteligencia Artificial A 9
# Error R1: Salon: 3 Curso a comparar: ipc2 D 5 . Salon:4 Curso con el que se comparo:ipc2 D 5
# Error R2: Salon: 3 Curso a comparar: ipc2 D 5 . Curso con el que se comparo:ipc2 D 5
# Error R2: Salon: 3 Curso a comparar: ipc2 D 5 . Curso con el que se comparo:ipc2 D 5
# Error R1: Salon: 4 Curso a comparar: Inteligencia Artificial A 1 . Salon:1 Curso con el que se comparo:Inteligencia Artificial A 1
# Error R1: Salon: 4 Curso a comparar: ipc2 D 5 . Salon:3 Curso con el que se comparo:ipc2 D 5
# Error R2: Salon: 5 Curso a comparar: Inteligencia Artificial A 9 . Curso con el que se comparo:Inteligencia Artificial A 9
# Error R2: Salon: 5 Curso a comparar: Inteligencia Artificial A 9 . Curso con el que se comparo:Inteligencia Artificial A 9
# Error R1: Salon: 5 Curso a comparar: Inteligencia Artificial A 9 . Salon:1 Curso con el que se comparo:Inteligencia Artificial A 9
# Error R2: Salon: 5 Curso a comparar: Inteligencia Artificial A 9 . Curso con el que se comparo:Inteligencia Artificial A 9
# Error R2: Salon: 5 Curso a comparar: Inteligencia Artificial A 9 . Curso con el que se comparo:Inteligencia Artificial A 9
# Error R2: Salon: 5 Curso a comparar: Inteligencia Artificial A 9 . Curso con el que se comparo:Inteligencia Artificial A 9
# Error R2: Salon: 5 Curso a comparar: Inteligencia Artificial A 9 . Curso con el que se comparo:Inteligencia Artificial A 9
# Error R1: Salon: 6 Curso a comparar: Teoria de Sistemas 1 B 6 . Salon:2 Curso con el que se comparo:Teoria de Sistemas 1 B 6
# Error R1: Salon: 6 Curso a comparar: Inteligencia Artificial A 9 . Salon:3 Curso con el que se comparo:Inteligencia Artificial A 9
# Error R2: Salon: 6 Curso a comparar: lenguajes E 4 . Curso con el que se comparo:lenguajes E 4
# Error R2: Salon: 6 Curso a comparar: Matemática Computo 1 A 3 . Curso con el que se comparo:Matemática Computo 1 A 3
# Error R2: Salon: 6 Curso a comparar: lenguajes E 4 . Curso con el que se comparo:lenguajes E 4
# Error R2: Salon: 6 Curso a comparar: Matemática Computo 1 A 3 . Curso con el que se comparo:Matemática Computo 1 A 3
# *****CROMSOMA 5****************
# Error R1: Salon: 1 Curso a comparar: Matemática Aplicada 1 A 8 . Salon:3 Curso con el que se comparo:Matemática Aplicada 1 A 8
# Error R1: Salon: 1 Curso a comparar: Inteligencia Artificial A 1 . Salon:5 Curso con el que se comparo:Inteligencia Artificial A 1
# Error R1: Salon: 1 Curso a comparar: Fisica basica B 2 . Salon:5 Curso con el que se comparo:Tecnica Complementaria 1 B 2
# Error R1: Salon: 2 Curso a comparar: Matemática Computo 1 A 3 . Salon:4 Curso con el que se comparo:Matemática Computo 1 A 3
# Error R1: Salon: 2 Curso a comparar: Matemática Computo 1 A 3 . Salon:6 Curso con el que se comparo:IPC1 A 3
# Error R1: Salon: 2 Curso a comparar: IPC1 A 3 . Salon:3 Curso con el que se comparo:IPC1 A 3
# Error R1: Salon: 3 Curso a comparar: Matemática Aplicada 1 A 8 . Salon:1 Curso con el que se comparo:Matemática Aplicada 1 A 8
# Error R1: Salon: 3 Curso a comparar: Teoria de Sistemas 1 B 6 . Salon:5 Curso con el que se comparo:Teoria de Sistemas 1 B 6
# Error R1: Salon: 3 Curso a comparar: IPC1 A 3 . Salon:2 Curso con el que se comparo:IPC1 A 3
# Error R2: Salon: 3 Curso a comparar: IPC1 A 3 . Curso con el que se comparo:IPC1 A 3
# Error R2: Salon: 3 Curso a comparar: IPC1 A 3 . Curso con el que se comparo:IPC1 A 3
# Error R1: Salon: 4 Curso a comparar: Matemática Computo 1 A 3 . Salon:2 Curso con el que se comparo:Matemática Computo 1 A 3
# Error R1: Salon: 4 Curso a comparar: Matemática Computo 1 A 3 . Salon:6 Curso con el que se comparo:IPC1 A 3
# Error R1: Salon: 5 Curso a comparar: Teoria de Sistemas 1 B 6 . Salon:3 Curso con el que se comparo:Teoria de Sistemas 1 B 6
# Error R2: Salon: 5 Curso a comparar: Inteligencia Artificial A 1 . Curso con el que se comparo:Inteligencia Artificial A 1
# Error R1: Salon: 5 Curso a comparar: Inteligencia Artificial A 1 . Salon:1 Curso con el que se comparo:Inteligencia Artificial A 1
# Error R2: Salon: 5 Curso a comparar: Inteligencia Artificial A 1 . Curso con el que se comparo:Inteligencia Artificial A 1
# Error R1: Salon: 5 Curso a comparar: Tecnica Complementaria 1 B 2 . Salon:1 Curso con el que se comparo:Fisica basica B 2
# Error R1: Salon: 6 Curso a comparar: IPC1 A 3 . Salon:2 Curso con el que se comparo:Matemática Computo 1 A 3
# Error R1: Salon: 6 Curso a comparar: IPC1 A 3 . Salon:4 Curso con el que se comparo:Matemática Computo 1 A 3
# Error R2: Salon: 6 Curso a comparar: IPC1 A 3 . Curso con el que se comparo:IPC1 A 3
# Error R2: Salon: 6 Curso a comparar: Matemática Aplicada 1 A 8 . Curso con el que se comparo:Matemática Aplicada 1 A 8
# Error R2: Salon: 6 Curso a comparar: IPC1 A 3 . Curso con el que se comparo:IPC1 A 3
# Error R2: Salon: 6 Curso a comparar: Matemática Aplicada 1 A 8 . Curso con el que se comparo:Matemática Aplicada 1 A 8
# *****CROMSOMA 6****************
# Error R2: Salon: 1 Curso a comparar: ipc1 C 4 . Curso con el que se comparo:ipc1 C 4
# Error R2: Salon: 1 Curso a comparar: ipc1 C 4 . Curso con el que se comparo:ipc1 C 4
# Error R2: Salon: 1 Curso a comparar: ipc1 C 4 . Curso con el que se comparo:ipc1 C 4
# Error R2: Salon: 1 Curso a comparar: ipc1 C 4 . Curso con el que se comparo:ipc1 C 4
# Error R1: Salon: 1 Curso a comparar: Compiladores 2 B 6 . Salon:4 Curso con el que se comparo:Compiladores 2 B 6
# Error R2: Salon: 1 Curso a comparar: ipc1 C 4 . Curso con el que se comparo:ipc1 C 4
# Error R2: Salon: 1 Curso a comparar: ipc1 C 4 . Curso con el que se comparo:ipc1 C 4
# Error R1: Salon: 2 Curso a comparar: Inteligencia Artificial A 9 . Salon:4 Curso con el que se comparo:Inteligencia Artificial A 9
# Error R1: Salon: 2 Curso a comparar: lenguajes E 4 . Salon:5 Curso con el que se comparo:lenguajes E 4
# Error R2: Salon: 2 Curso a comparar: lenguajes E 4 . Curso con el que se comparo:lenguajes E 4
# Error R2: Salon: 2 Curso a comparar: lenguajes E 4 . Curso con el que se comparo:lenguajes E 4
# Error R2: Salon: 2 Curso a comparar: lenguajes E 4 . Curso con el que se comparo:lenguajes E 4
# Error R2: Salon: 2 Curso a comparar: lenguajes E 4 . Curso con el que se comparo:lenguajes E 4
# Error R1: Salon: 2 Curso a comparar: Fisica basica B 2 . Salon:6 Curso con el que se comparo:Fisica basica B 2
# Error R1: Salon: 2 Curso a comparar: lenguajes E 4 . Salon:6 Curso con el que se comparo:lenguajes E 4
# Error R2: Salon: 2 Curso a comparar: lenguajes E 4 . Curso con el que se comparo:lenguajes E 4
# Error R2: Salon: 2 Curso a comparar: lenguajes E 4 . Curso con el que se comparo:lenguajes E 4
# Error R1: Salon: 3 Curso a comparar: Matemática Computo 1 A 3 . Salon:5 Curso con el que se comparo:IPC1 A 3
# Error R2: Salon: 3 Curso a comparar: Matemática Computo 1 A 3 . Curso con el que se comparo:Matemática Computo 1 A 3
# Error R2: Salon: 3 Curso a comparar: Matemática Aplicada 3 B 7 . Curso con el que se comparo:Matemática Aplicada 3 B 7
# Error R2: Salon: 3 Curso a comparar: Matemática Computo 1 A 3 . Curso con el que se comparo:Matemática Computo 1 A 3
# Error R1: Salon: 3 Curso a comparar: Matemática Aplicada 3 B 7 . Salon:6 Curso con el que se comparo:Matemática Aplicada 3 B 7
# Error R2: Salon: 3 Curso a comparar: Matemática Aplicada 3 B 7 . Curso con el que se comparo:Matemática Aplicada 3 B 7
# Error R1: Salon: 4 Curso a comparar: Inteligencia Artificial A 9 . Salon:2 Curso con el que se comparo:Inteligencia Artificial A 9
# Error R1: Salon: 4 Curso a comparar: Compiladores 2 B 6 . Salon:1 Curso con el que se comparo:Compiladores 2 B 6
# Error R1: Salon: 5 Curso a comparar: IPC1 A 3 . Salon:3 Curso con el que se comparo:Matemática Computo 1 A 3
# Error R1: Salon: 5 Curso a comparar: lenguajes E 4 . Salon:2 Curso con el que se comparo:lenguajes E 4
# Error R2: Salon: 5 Curso a comparar: Matematica basica 1 A 1 . Curso con el que se comparo:Matematica basica 1 A 1
# Error R2: Salon: 5 Curso a comparar: Matematica basica 1 A 1 . Curso con el que se comparo:Matematica basica 1 A 1
# Error R2: Salon: 6 Curso a comparar: Fisica basica B 2 . Curso con el que se comparo:Fisica basica B 2
# Error R1: Salon: 6 Curso a comparar: Matemática Aplicada 3 B 7 . Salon:3 Curso con el que se comparo:Matemática Aplicada 3 B 7
# Error R1: Salon: 6 Curso a comparar: Fisica basica B 2 . Salon:2 Curso con el que se comparo:Fisica basica B 2
# Error R2: Salon: 6 Curso a comparar: Fisica basica B 2 . Curso con el que se comparo:Fisica basica B 2
# Error R1: Salon: 6 Curso a comparar: lenguajes E 4 . Salon:2 Curso con el que se comparo:lenguajes E 4
# *****CROMSOMA 7****************
# Error R2: Salon: 1 Curso a comparar: Compiladores 1 D 1 . Curso con el que se comparo:Compiladores 1 D 1
# Error R2: Salon: 1 Curso a comparar: Compiladores 1 D 1 . Curso con el que se comparo:Compiladores 1 D 1
# Error R1: Salon: 2 Curso a comparar: Compiladores 2 B 6 . Salon:6 Curso con el que se comparo:Compiladores 2 B 6
# Error R1: Salon: 2 Curso a comparar: ipc2 D 5 . Salon:5 Curso con el que se comparo:ipc2 D 5
# Error R2: Salon: 2 Curso a comparar: ipc2 D 5 . Curso con el que se comparo:ipc2 D 5
# Error R1: Salon: 2 Curso a comparar: Teoria de Sistemas 1 B 6 . Salon:4 Curso con el que se comparo:Teoria de Sistemas 1 B 6
# Error R1: Salon: 2 Curso a comparar: Fisica basica B 2 . Salon:6 Curso con el que se comparo:Tecnica Complementaria 1 B 2
# Error R2: Salon: 2 Curso a comparar: ipc2 D 5 . Curso con el que se comparo:ipc2 D 5
# Error R1: Salon: 3 Curso a comparar: Fisica basica B 2 . Salon:4 Curso con el que se comparo:Fisica basica B 2
# Error R1: Salon: 3 Curso a comparar: ipc2 D 5 . Salon:5 Curso con el que se comparo:ipc2 D 5
# Error R2: Salon: 3 Curso a comparar: Matemática Aplicada 3 B 7 . Curso con el que se comparo:Matemática Aplicada 3 B 7
# Error R2: Salon: 3 Curso a comparar: Matemática Aplicada 3 B 7 . Curso con el que se comparo:Matemática Aplicada 3 B 7
# Error R1: Salon: 4 Curso a comparar: Fisica basica B 2 . Salon:3 Curso con el que se comparo:Fisica basica B 2
# Error R2: Salon: 4 Curso a comparar: Matemática Aplicada 1 A 8 . Curso con el que se comparo:Matemática Aplicada 1 A 8
# Error R1: Salon: 4 Curso a comparar: Teoria de Sistemas 1 B 6 . Salon:2 Curso con el que se comparo:Teoria de Sistemas 1 B 6
# Error R2: Salon: 4 Curso a comparar: Teoria de Sistemas 1 B 6 . Curso con el que se comparo:Teoria de Sistemas 1 B 6
# Error R2: Salon: 4 Curso a comparar: Teoria de Sistemas 1 B 6 . Curso con el que se comparo:Teoria de Sistemas 1 B 6
# Error R1: Salon: 4 Curso a comparar: Matematica basica 1 A 1 . Salon:5 Curso con el que se comparo:Inteligencia Artificial A 1
# Error R2: Salon: 4 Curso a comparar: Matemática Aplicada 1 A 8 . Curso con el que se comparo:Matemática Aplicada 1 A 8
# Error R1: Salon: 5 Curso a comparar: ipc2 D 5 . Salon:2 Curso con el que se comparo:ipc2 D 5
# Error R2: Salon: 5 Curso a comparar: ipc2 D 5 . Curso con el que se comparo:ipc2 D 5
# Error R1: Salon: 5 Curso a comparar: ipc2 D 5 . Salon:3 Curso con el que se comparo:ipc2 D 5
# Error R2: Salon: 5 Curso a comparar: ipc2 D 5 . Curso con el que se comparo:ipc2 D 5
# Error R1: Salon: 5 Curso a comparar: Inteligencia Artificial A 1 . Salon:4 Curso con el que se comparo:Matematica basica 1 A 1
# Error R1: Salon: 5 Curso a comparar: IPC1 A 3 . Salon:6 Curso con el que se comparo:IPC1 A 3
# Error R1: Salon: 6 Curso a comparar: Compiladores 2 B 6 . Salon:2 Curso con el que se comparo:Compiladores 2 B 6
# Error R2: Salon: 6 Curso a comparar: IPC1 A 3 . Curso con el que se comparo:IPC1 A 3
# Error R1: Salon: 6 Curso a comparar: Tecnica Complementaria 1 B 2 . Salon:2 Curso con el que se comparo:Fisica basica B 2
# Error R1: Salon: 6 Curso a comparar: IPC1 A 3 . Salon:5 Curso con el que se comparo:IPC1 A 3
# Error R2: Salon: 6 Curso a comparar: IPC1 A 3 . Curso con el que se comparo:IPC1 A 3
# *****CROMSOMA 8****************
# Error R2: Salon: 1 Curso a comparar: ipc1 C 4 . Curso con el que se comparo:ipc1 C 4
# Error R1: Salon: 1 Curso a comparar: so1 C 6 . Salon:6 Curso con el que se comparo:so1 C 6
# Error R1: Salon: 1 Curso a comparar: Matemática Aplicada 3 B 7 . Salon:2 Curso con el que se comparo:Matemática Aplicada 3 B 7
# Error R2: Salon: 1 Curso a comparar: ipc1 C 4 . Curso con el que se comparo:ipc1 C 4
# Error R1: Salon: 2 Curso a comparar: Matemática Aplicada 3 B 7 . Salon:1 Curso con el que se comparo:Matemática Aplicada 3 B 7
# Error R1: Salon: 2 Curso a comparar: IPC1 A 3 . Salon:6 Curso con el que se comparo:Matemática Computo 1 A 3
# Error R1: Salon: 2 Curso a comparar: so1 C 6 . Salon:3 Curso con el que se comparo:so1 C 6
# Error R1: Salon: 3 Curso a comparar: IPC1 A 3 . Salon:4 Curso con el que se comparo:IPC1 A 3
# Error R1: Salon: 3 Curso a comparar: Compiladores 2 B 6 . Salon:6 Curso con el que se comparo:Teoria de Sistemas 1 B 6
# Error R1: Salon: 3 Curso a comparar: so1 C 6 . Salon:2 Curso con el que se comparo:so1 C 6
# Error R1: Salon: 4 Curso a comparar: IPC1 A 3 . Salon:3 Curso con el que se comparo:IPC1 A 3
# Error R2: Salon: 5 Curso a comparar: Teoria de Sistemas 1 B 6 . Curso con el que se comparo:Teoria de Sistemas 1 B 6
# Error R2: Salon: 5 Curso a comparar: Teoria de Sistemas 1 B 6 . Curso con el que se comparo:Teoria de Sistemas 1 B 6
# Error R2: Salon: 5 Curso a comparar: Inteligencia Artificial A 9 . Curso con el que se comparo:Inteligencia Artificial A 9
# Error R1: Salon: 5 Curso a comparar: Teoria de Sistemas 1 B 6 . Salon:6 Curso con el que se comparo:Compiladores 2 B 6
# Error R2: Salon: 5 Curso a comparar: Teoria de Sistemas 1 B 6 . Curso con el que se comparo:Teoria de Sistemas 1 B 6
# Error R2: Salon: 5 Curso a comparar: Teoria de Sistemas 1 B 6 . Curso con el que se comparo:Teoria de Sistemas 1 B 6
# Error R2: Salon: 5 Curso a comparar: Inteligencia Artificial A 9 . Curso con el que se comparo:Inteligencia Artificial A 9
# Error R2: Salon: 5 Curso a comparar: Teoria de Sistemas 1 B 6 . Curso con el que se comparo:Teoria de Sistemas 1 B 6
# Error R2: Salon: 5 Curso a comparar: Teoria de Sistemas 1 B 6 . Curso con el que se comparo:Teoria de Sistemas 1 B 6
# Error R2: Salon: 6 Curso a comparar: Matemática Computo 1 A 3 . Curso con el que se comparo:Matemática Computo 1 A 3
# Error R1: Salon: 6 Curso a comparar: so1 C 6 . Salon:1 Curso con el que se comparo:so1 C 6
# Error R1: Salon: 6 Curso a comparar: Compiladores 2 B 6 . Salon:5 Curso con el que se comparo:Teoria de Sistemas 1 B 6
# Error R1: Salon: 6 Curso a comparar: Teoria de Sistemas 1 B 6 . Salon:3 Curso con el que se comparo:Compiladores 2 B 6
# Error R1: Salon: 6 Curso a comparar: Matemática Computo 1 A 3 . Salon:2 Curso con el que se comparo:IPC1 A 3
# Error R2: Salon: 6 Curso a comparar: Matemática Computo 1 A 3 . Curso con el que se comparo:Matemática Computo 1 A 3
# *****CROMSOMA 9****************
# Error R2: Salon: 1 Curso a comparar: Matemática Aplicada 1 A 8 . Curso con el que se comparo:Matemática Aplicada 1 A 8
# Error R2: Salon: 1 Curso a comparar: Matemática Aplicada 1 A 8 . Curso con el que se comparo:Matemática Aplicada 1 A 8
# Error R1: Salon: 1 Curso a comparar: Inteligencia Artificial A 9 . Salon:3 Curso con el que se comparo:Inteligencia Artificial A 9
# Error R1: Salon: 1 Curso a comparar: Matemática Computo 1 A 3 . Salon:6 Curso con el que se comparo:Matemática Computo 1 A 3
# Error R1: Salon: 2 Curso a comparar: Tecnica Complementaria 1 B 2 . Salon:6 Curso con el que se comparo:Tecnica Complementaria 1 B 2
# Error R1: Salon: 2 Curso a comparar: Teoria de Sistemas 1 B 6 . Salon:6 Curso con el que se comparo:Teoria de Sistemas 1 B 6
# Error R2: Salon: 2 Curso a comparar: Teoria de Sistemas 1 B 6 . Curso con el que se comparo:Teoria de Sistemas 1 B 6
# Error R2: Salon: 2 Curso a comparar: Inteligencia Artificial A 9 . Curso con el que se comparo:Inteligencia Artificial A 9
# Error R1: Salon: 2 Curso a comparar: Inteligencia Artificial A 9 . Salon:4 Curso con el que se comparo:Inteligencia Artificial A 9
# Error R2: Salon: 2 Curso a comparar: Inteligencia Artificial A 9 . Curso con el que se comparo:Inteligencia Artificial A 9
# Error R2: Salon: 2 Curso a comparar: Teoria de Sistemas 1 B 6 . Curso con el que se comparo:Teoria de Sistemas 1 B 6
# Error R2: Salon: 3 Curso a comparar: ipc1 C 4 . Curso con el que se comparo:ipc1 C 4
# Error R1: Salon: 3 Curso a comparar: Inteligencia Artificial A 9 . Salon:1 Curso con el que se comparo:Inteligencia Artificial A 9
# Error R2: Salon: 3 Curso a comparar: ipc1 C 4 . Curso con el que se comparo:ipc1 C 4
# Error R1: Salon: 4 Curso a comparar: Inteligencia Artificial A 9 . Salon:2 Curso con el que se comparo:Inteligencia Artificial A 9
# Error R2: Salon: 4 Curso a comparar: Tecnica Complementaria 1 B 2 . Curso con el que se comparo:Tecnica Complementaria 1 B 2
# Error R2: Salon: 4 Curso a comparar: Tecnica Complementaria 1 B 2 . Curso con el que se comparo:Tecnica Complementaria 1 B 2
# Error R2: Salon: 5 Curso a comparar: Matemática Computo 1 A 3 . Curso con el que se comparo:Matemática Computo 1 A 3
# Error R1: Salon: 5 Curso a comparar: Matemática Computo 1 A 3 . Salon:6 Curso con el que se comparo:IPC1 A 3
# Error R2: Salon: 5 Curso a comparar: Matemática Computo 1 A 3 . Curso con el que se comparo:Matemática Computo 1 A 3
# Error R1: Salon: 5 Curso a comparar: ipc1 C 4 . Salon:6 Curso con el que se comparo:ipc1 C 4
# Error R1: Salon: 6 Curso a comparar: Tecnica Complementaria 1 B 2 . Salon:2 Curso con el que se comparo:Tecnica Complementaria 1 B 2
# Error R1: Salon: 6 Curso a comparar: Teoria de Sistemas 1 B 6 . Salon:2 Curso con el que se comparo:Teoria de Sistemas 1 B 6
# Error R1: Salon: 6 Curso a comparar: IPC1 A 3 . Salon:5 Curso con el que se comparo:Matemática Computo 1 A 3
# Error R1: Salon: 6 Curso a comparar: ipc1 C 4 . Salon:5 Curso con el que se comparo:ipc1 C 4
# Error R1: Salon: 6 Curso a comparar: Matemática Computo 1 A 3 . Salon:1 Curso con el que se comparo:Matemática Computo 1 A 3
# *****CROMSOMA 10****************
# Error R1: Salon: 1 Curso a comparar: lenguajes E 4 . Salon:5 Curso con el que se comparo:lenguajes E 4
# Error R2: Salon: 1 Curso a comparar: lenguajes E 4 . Curso con el que se comparo:lenguajes E 4
# Error R1: Salon: 1 Curso a comparar: Compiladores 1 D 1 . Salon:4 Curso con el que se comparo:Compiladores 1 D 1
# Error R2: Salon: 1 Curso a comparar: lenguajes E 4 . Curso con el que se comparo:lenguajes E 4
# Error R1: Salon: 2 Curso a comparar: Tecnica Complementaria 1 B 2 . Salon:6 Curso con el que se comparo:Fisica basica B 2
# Error R1: Salon: 2 Curso a comparar: so1 C 6 . Salon:5 Curso con el que se comparo:so1 C 6
# Error R2: Salon: 2 Curso a comparar: so1 C 6 . Curso con el que se comparo:so1 C 6
# Error R1: Salon: 2 Curso a comparar: so1 C 6 . Salon:4 Curso con el que se comparo:so1 C 6
# Error R2: Salon: 2 Curso a comparar: so1 C 6 . Curso con el que se comparo:so1 C 6
# Error R1: Salon: 3 Curso a comparar: Fisica basica B 2 . Salon:6 Curso con el que se comparo:Fisica basica B 2
# Error R2: Salon: 3 Curso a comparar: IPC1 A 3 . Curso con el que se comparo:IPC1 A 3
# Error R2: Salon: 3 Curso a comparar: IPC1 A 3 . Curso con el que se comparo:IPC1 A 3
# Error R1: Salon: 4 Curso a comparar: Compiladores 1 D 1 . Salon:1 Curso con el que se comparo:Compiladores 1 D 1
# Error R1: Salon: 4 Curso a comparar: so1 C 6 . Salon:2 Curso con el que se comparo:so1 C 6
# Error R1: Salon: 5 Curso a comparar: lenguajes E 4 . Salon:1 Curso con el que se comparo:lenguajes E 4
# Error R1: Salon: 5 Curso a comparar: so1 C 6 . Salon:2 Curso con el que se comparo:so1 C 6
# Error R1: Salon: 6 Curso a comparar: Fisica basica B 2 . Salon:3 Curso con el que se comparo:Fisica basica B 2
# Error R2: Salon: 6 Curso a comparar: Fisica basica B 2 . Curso con el que se comparo:Fisica basica B 2
# Error R1: Salon: 6 Curso a comparar: Fisica basica B 2 . Salon:2 Curso con el que se comparo:Tecnica Complementaria 1 B 2
# Error R2: Salon: 6 Curso a comparar: Fisica basica B 2 . Curso con el que se comparo:Fisica basica B 2
# *****CROMSOMA 11****************
# Error R2: Salon: 1 Curso a comparar: Compiladores 1 D 1 . Curso con el que se comparo:Compiladores 1 D 1
# Error R1: Salon: 1 Curso a comparar: Compiladores 2 B 6 . Salon:4 Curso con el que se comparo:Compiladores 2 B 6
# Error R1: Salon: 1 Curso a comparar: Compiladores 1 D 1 . Salon:3 Curso con el que se comparo:Compiladores 1 D 1
# Error R2: Salon: 1 Curso a comparar: Compiladores 1 D 1 . Curso con el que se comparo:Compiladores 1 D 1
# Error R1: Salon: 2 Curso a comparar: Matemática Aplicada 1 A 8 . Salon:3 Curso con el que se comparo:Matemática Aplicada 1 A 8
# Error R2: Salon: 2 Curso a comparar: Matemática Aplicada 1 A 8 . Curso con el que se comparo:Matemática Aplicada 1 A 8
# Error R1: Salon: 2 Curso a comparar: Teoria de Sistemas 1 B 6 . Salon:6 Curso con el que se comparo:Compiladores 2 B 6
# Error R2: Salon: 2 Curso a comparar: Matemática Aplicada 1 A 8 . Curso con el que se comparo:Matemática Aplicada 1 A 8
# Error R1: Salon: 3 Curso a comparar: Matemática Aplicada 1 A 8 . Salon:2 Curso con el que se comparo:Matemática Aplicada 1 A 8
# Error R2: Salon: 3 Curso a comparar: Compiladores 1 D 1 . Curso con el que se comparo:Compiladores 1 D 1
# Error R1: Salon: 3 Curso a comparar: Compiladores 1 D 1 . Salon:1 Curso con el que se comparo:Compiladores 1 D 1
# Error R2: Salon: 3 Curso a comparar: Compiladores 1 D 1 . Curso con el que se comparo:Compiladores 1 D 1
# Error R1: Salon: 4 Curso a comparar: so1 C 6 . Salon:5 Curso con el que se comparo:so1 C 6
# Error R2: Salon: 4 Curso a comparar: so1 C 6 . Curso con el que se comparo:so1 C 6
# Error R1: Salon: 4 Curso a comparar: Compiladores 2 B 6 . Salon:1 Curso con el que se comparo:Compiladores 2 B 6
# Error R2: Salon: 4 Curso a comparar: so1 C 6 . Curso con el que se comparo:so1 C 6
# Error R1: Salon: 5 Curso a comparar: so1 C 6 . Salon:4 Curso con el que se comparo:so1 C 6
# Error R2: Salon: 5 Curso a comparar: lenguajes E 4 . Curso con el que se comparo:lenguajes E 4
# Error R1: Salon: 5 Curso a comparar: IPC1 A 3 . Salon:6 Curso con el que se comparo:Matemática Computo 1 A 3
# Error R2: Salon: 5 Curso a comparar: lenguajes E 4 . Curso con el que se comparo:lenguajes E 4
# Error R1: Salon: 6 Curso a comparar: Compiladores 2 B 6 . Salon:2 Curso con el que se comparo:Teoria de Sistemas 1 B 6
# Error R1: Salon: 6 Curso a comparar: Matemática Computo 1 A 3 . Salon:5 Curso con el que se comparo:IPC1 A 3
# Error R2: Salon: 6 Curso a comparar: Matemática Computo 1 A 3 . Curso con el que se comparo:Matemática Computo 1 A 3
# Error R2: Salon: 6 Curso a comparar: Matemática Computo 1 A 3 . Curso con el que se comparo:Matemática Computo 1 A 3
# *****CROMSOMA 12****************
# Error R2: Salon: 1 Curso a comparar: Fisica basica B 2 . Curso con el que se comparo:Fisica basica B 2
# Error R1: Salon: 1 Curso a comparar: IPC1 A 3 . Salon:6 Curso con el que se comparo:IPC1 A 3
# Error R1: Salon: 1 Curso a comparar: Fisica basica B 2 . Salon:2 Curso con el que se comparo:Fisica basica B 2
# Error R2: Salon: 1 Curso a comparar: Fisica basica B 2 . Curso con el que se comparo:Fisica basica B 2
# Error R1: Salon: 2 Curso a comparar: Teoria de Sistemas 1 B 6 . Salon:3 Curso con el que se comparo:Compiladores 2 B 6
# Error R1: Salon: 2 Curso a comparar: Matematica basica 1 A 1 . Salon:5 Curso con el que se comparo:Matematica basica 1 A 1
# Error R1: Salon: 2 Curso a comparar: Fisica basica B 2 . Salon:1 Curso con el que se comparo:Fisica basica B 2
# Error R2: Salon: 3 Curso a comparar: Compiladores 1 D 1 . Curso con el que se comparo:Compiladores 1 D 1
# Error R1: Salon: 3 Curso a comparar: Matemática Computo 1 A 3 . Salon:4 Curso con el que se comparo:IPC1 A 3
# Error R1: Salon: 3 Curso a comparar: Compiladores 2 B 6 . Salon:2 Curso con el que se comparo:Teoria de Sistemas 1 B 6
# Error R2: Salon: 3 Curso a comparar: Compiladores 1 D 1 . Curso con el que se comparo:Compiladores 1 D 1
# Error R1: Salon: 3 Curso a comparar: Matemática Aplicada 3 B 7 . Salon:6 Curso con el que se comparo:Matemática Aplicada 3 B 7
# Error R1: Salon: 4 Curso a comparar: Matematica basica 1 A 1 . Salon:6 Curso con el que se comparo:Inteligencia Artificial A 1
# Error R1: Salon: 4 Curso a comparar: IPC1 A 3 . Salon:3 Curso con el que se comparo:Matemática Computo 1 A 3
# Error R2: Salon: 5 Curso a comparar: Inteligencia Artificial A 9 . Curso con el que se comparo:Inteligencia Artificial A 9
# Error R1: Salon: 5 Curso a comparar: Matematica basica 1 A 1 . Salon:2 Curso con el que se comparo:Matematica basica 1 A 1
# Error R2: Salon: 5 Curso a comparar: Inteligencia Artificial A 9 . Curso con el que se comparo:Inteligencia Artificial A 9
# Error R1: Salon: 6 Curso a comparar: Inteligencia Artificial A 1 . Salon:4 Curso con el que se comparo:Matematica basica 1 A 1
# Error R1: Salon: 6 Curso a comparar: IPC1 A 3 . Salon:1 Curso con el que se comparo:IPC1 A 3
# Error R1: Salon: 6 Curso a comparar: Matemática Aplicada 3 B 7 . Salon:3 Curso con el que se comparo:Matemática Aplicada 3 B 7
# *****CROMSOMA 13****************
# Error R2: Salon: 1 Curso a comparar: Compiladores 2 B 6 . Curso con el que se comparo:Compiladores 2 B 6
# Error R2: Salon: 1 Curso a comparar: Compiladores 2 B 6 . Curso con el que se comparo:Compiladores 2 B 6
# Error R1: Salon: 1 Curso a comparar: Compiladores 1 D 1 . Salon:6 Curso con el que se comparo:Compiladores 1 D 1
# Error R2: Salon: 1 Curso a comparar: Compiladores 1 D 1 . Curso con el que se comparo:Compiladores 1 D 1
# Error R1: Salon: 1 Curso a comparar: Matemática Computo 1 A 3 . Salon:3 Curso con el que se comparo:Matemática Computo 1 A 3
# Error R1: Salon: 1 Curso a comparar: Matemática Aplicada 3 B 7 . Salon:6 Curso con el que se comparo:Matemática Aplicada 3 B 7
# Error R2: Salon: 1 Curso a comparar: Compiladores 1 D 1 . Curso con el que se comparo:Compiladores 1 D 1
# Error R1: Salon: 2 Curso a comparar: ipc2 D 5 . Salon:5 Curso con el que se comparo:ipc2 D 5
# Error R1: Salon: 2 Curso a comparar: Matematica basica 1 A 1 . Salon:4 Curso con el que se comparo:Matematica basica 1 A 1
# Error R1: Salon: 2 Curso a comparar: Inteligencia Artificial A 1 . Salon:4 Curso con el que se comparo:Inteligencia Artificial A 1
# Error R1: Salon: 2 Curso a comparar: Inteligencia Artificial A 1 . Salon:5 Curso con el que se comparo:Matematica basica 1 A 1
# Error R2: Salon: 2 Curso a comparar: Inteligencia Artificial A 1 . Curso con el que se comparo:Inteligencia Artificial A 1
# Error R1: Salon: 2 Curso a comparar: Inteligencia Artificial A 1 . Salon:5 Curso con el que se comparo:Inteligencia Artificial A 1
# Error R2: Salon: 2 Curso a comparar: Inteligencia Artificial A 1 . Curso con el que se comparo:Inteligencia Artificial A 1
# Error R2: Salon: 3 Curso a comparar: Matemática Computo 1 A 3 . Curso con el que se comparo:Matemática Computo 1 A 3
# Error R2: Salon: 3 Curso a comparar: Matemática Computo 1 A 3 . Curso con el que se comparo:Matemática Computo 1 A 3
# Error R1: Salon: 3 Curso a comparar: Compiladores 2 B 6 . Salon:5 Curso con el que se comparo:Teoria de Sistemas 1 B 6
# Error R2: Salon: 3 Curso a comparar: Compiladores 2 B 6 . Curso con el que se comparo:Compiladores 2 B 6
# Error R1: Salon: 3 Curso a comparar: Matemática Computo 1 A 3 . Salon:1 Curso con el que se comparo:Matemática Computo 1 A 3
# Error R2: Salon: 3 Curso a comparar: Matemática Computo 1 A 3 . Curso con el que se comparo:Matemática Computo 1 A 3
# Error R2: Salon: 3 Curso a comparar: Matemática Computo 1 A 3 . Curso con el que se comparo:Matemática Computo 1 A 3
# Error R1: Salon: 3 Curso a comparar: Matemática Computo 1 A 3 . Salon:4 Curso con el que se comparo:IPC1 A 3
# Error R2: Salon: 3 Curso a comparar: Matemática Computo 1 A 3 . Curso con el que se comparo:Matemática Computo 1 A 3
# Error R2: Salon: 3 Curso a comparar: Matemática Computo 1 A 3 . Curso con el que se comparo:Matemática Computo 1 A 3
# Error R1: Salon: 3 Curso a comparar: Compiladores 2 B 6 . Salon:5 Curso con el que se comparo:Compiladores 2 B 6
# Error R2: Salon: 3 Curso a comparar: Compiladores 2 B 6 . Curso con el que se comparo:Compiladores 2 B 6
# Error R1: Salon: 4 Curso a comparar: Tecnica Complementaria 1 B 2 . Salon:6 Curso con el que se comparo:Fisica basica B 2
# Error R1: Salon: 4 Curso a comparar: Matemática Computo 1 A 3 . Salon:6 Curso con el que se comparo:Matemática Computo 1 A 3
# Error R1: Salon: 4 Curso a comparar: Matematica basica 1 A 1 . Salon:2 Curso con el que se comparo:Matematica basica 1 A 1
# Error R1: Salon: 4 Curso a comparar: Inteligencia Artificial A 1 . Salon:2 Curso con el que se comparo:Inteligencia Artificial A 1
# Error R1: Salon: 4 Curso a comparar: Inteligencia Artificial A 1 . Salon:5 Curso con el que se comparo:Matematica basica 1 A 1
# Error R1: Salon: 4 Curso a comparar: IPC1 A 3 . Salon:3 Curso con el que se comparo:Matemática Computo 1 A 3
# Error R1: Salon: 5 Curso a comparar: ipc2 D 5 . Salon:2 Curso con el que se comparo:ipc2 D 5
# Error R1: Salon: 5 Curso a comparar: Teoria de Sistemas 1 B 6 . Salon:3 Curso con el que se comparo:Compiladores 2 B 6
# Error R1: Salon: 5 Curso a comparar: Matematica basica 1 A 1 . Salon:2 Curso con el que se comparo:Inteligencia Artificial A 1
# Error R1: Salon: 5 Curso a comparar: Matematica basica 1 A 1 . Salon:4 Curso con el que se comparo:Inteligencia Artificial A 1
# Error R1: Salon: 5 Curso a comparar: Inteligencia Artificial A 1 . Salon:2 Curso con el que se comparo:Inteligencia Artificial A 1
# Error R1: Salon: 5 Curso a comparar: Compiladores 2 B 6 . Salon:3 Curso con el que se comparo:Compiladores 2 B 6
# Error R1: Salon: 6 Curso a comparar: Fisica basica B 2 . Salon:4 Curso con el que se comparo:Tecnica Complementaria 1 B 2
# Error R1: Salon: 6 Curso a comparar: Matemática Computo 1 A 3 . Salon:4 Curso con el que se comparo:Matemática Computo 1 A 3
# Error R1: Salon: 6 Curso a comparar: Compiladores 1 D 1 . Salon:1 Curso con el que se comparo:Compiladores 1 D 1
# Error R2: Salon: 6 Curso a comparar: Compiladores 1 D 1 . Curso con el que se comparo:Compiladores 1 D 1
# Error R2: Salon: 6 Curso a comparar: Compiladores 1 D 1 . Curso con el que se comparo:Compiladores 1 D 1
# Error R1: Salon: 6 Curso a comparar: Matemática Aplicada 3 B 7 . Salon:1 Curso con el que se comparo:Matemática Aplicada 3 B 7
# *****CROMSOMA 14****************
# Error R1: Salon: 1 Curso a comparar: so1 C 6 . Salon:2 Curso con el que se comparo:so1 C 6
# Error R1: Salon: 1 Curso a comparar: IPC1 A 3 . Salon:2 Curso con el que se comparo:IPC1 A 3
# Error R1: Salon: 1 Curso a comparar: IPC1 A 3 . Salon:4 Curso con el que se comparo:Matemática Computo 1 A 3
# Error R1: Salon: 1 Curso a comparar: Matematica basica 1 A 1 . Salon:5 Curso con el que se comparo:Inteligencia Artificial A 1
# Error R1: Salon: 1 Curso a comparar: Compiladores 1 D 1 . Salon:2 Curso con el que se comparo:Compiladores 1 D 1
# Error R1: Salon: 2 Curso a comparar: so1 C 6 . Salon:1 Curso con el que se comparo:so1 C 6
# Error R1: Salon: 2 Curso a comparar: IPC1 A 3 . Salon:1 Curso con el que se comparo:IPC1 A 3
# Error R1: Salon: 2 Curso a comparar: IPC1 A 3 . Salon:4 Curso con el que se comparo:Matemática Computo 1 A 3
# Error R1: Salon: 2 Curso a comparar: Compiladores 1 D 1 . Salon:1 Curso con el que se comparo:Compiladores 1 D 1
# Error R2: Salon: 3 Curso a comparar: ipc1 C 4 . Curso con el que se comparo:ipc1 C 4
# Error R1: Salon: 3 Curso a comparar: Teoria de Sistemas 1 B 6 . Salon:6 Curso con el que se comparo:Teoria de Sistemas 1 B 6
# Error R2: Salon: 3 Curso a comparar: ipc1 C 4 . Curso con el que se comparo:ipc1 C 4
# Error R1: Salon: 3 Curso a comparar: IPC1 A 3 . Salon:6 Curso con el que se comparo:IPC1 A 3
# Error R1: Salon: 4 Curso a comparar: Matemática Computo 1 A 3 . Salon:1 Curso con el que se comparo:IPC1 A 3
# Error R1: Salon: 4 Curso a comparar: Matemática Computo 1 A 3 . Salon:2 Curso con el que se comparo:IPC1 A 3
# Error R2: Salon: 5 Curso a comparar: Inteligencia Artificial A 1 . Curso con el que se comparo:Inteligencia Artificial A 1
# Error R1: Salon: 5 Curso a comparar: Inteligencia Artificial A 1 . Salon:1 Curso con el que se comparo:Matematica basica 1 A 1
# Error R2: Salon: 5 Curso a comparar: Inteligencia Artificial A 1 . Curso con el que se comparo:Inteligencia Artificial A 1
# Error R2: Salon: 6 Curso a comparar: Matemática Aplicada 1 A 8 . Curso con el que se comparo:Matemática Aplicada 1 A 8
# Error R1: Salon: 6 Curso a comparar: Teoria de Sistemas 1 B 6 . Salon:3 Curso con el que se comparo:Teoria de Sistemas 1 B 6
# Error R2: Salon: 6 Curso a comparar: Matemática Aplicada 1 A 8 . Curso con el que se comparo:Matemática Aplicada 1 A 8
# Error R1: Salon: 6 Curso a comparar: IPC1 A 3 . Salon:3 Curso con el que se comparo:IPC1 A 3
# *****CROMSOMA 15****************
# Error R2: Salon: 1 Curso a comparar: Matematica basica 1 A 1 . Curso con el que se comparo:Matematica basica 1 A 1
# Error R2: Salon: 1 Curso a comparar: Matematica basica 1 A 1 . Curso con el que se comparo:Matematica basica 1 A 1
# Error R2: Salon: 1 Curso a comparar: Tecnica Complementaria 1 B 2 . Curso con el que se comparo:Tecnica Complementaria 1 B 2
# Error R1: Salon: 1 Curso a comparar: Fisica basica B 2 . Salon:4 Curso con el que se comparo:Tecnica Complementaria 1 B 2
# Error R1: Salon: 1 Curso a comparar: Tecnica Complementaria 1 B 2 . Salon:3 Curso con el que se comparo:Tecnica Complementaria 1 B 2
# Error R2: Salon: 1 Curso a comparar: Tecnica Complementaria 1 B 2 . Curso con el que se comparo:Tecnica Complementaria 1 B 2
# Error R1: Salon: 2 Curso a comparar: Inteligencia Artificial A 9 . Salon:6 Curso con el que se comparo:Inteligencia Artificial A 9
# Error R1: Salon: 2 Curso a comparar: Teoria de Sistemas 1 B 6 . Salon:3 Curso con el que se comparo:Teoria de Sistemas 1 B 6
# Error R1: Salon: 2 Curso a comparar: Inteligencia Artificial A 1 . Salon:4 Curso con el que se comparo:Matematica basica 1 A 1
# Error R1: Salon: 2 Curso a comparar: Compiladores 1 D 1 . Salon:4 Curso con el que se comparo:Compiladores 1 D 1
# Error R2: Salon: 3 Curso a comparar: Compiladores 1 D 1 . Curso con el que se comparo:Compiladores 1 D 1
# Error R2: Salon: 3 Curso a comparar: Compiladores 2 B 6 . Curso con el que se comparo:Compiladores 2 B 6
# Error R1: Salon: 3 Curso a comparar: Teoria de Sistemas 1 B 6 . Salon:2 Curso con el que se comparo:Teoria de Sistemas 1 B 6
# Error R2: Salon: 3 Curso a comparar: Compiladores 1 D 1 . Curso con el que se comparo:Compiladores 1 D 1
# Error R2: Salon: 3 Curso a comparar: Compiladores 2 B 6 . Curso con el que se comparo:Compiladores 2 B 6
# Error R1: Salon: 3 Curso a comparar: Tecnica Complementaria 1 B 2 . Salon:1 Curso con el que se comparo:Tecnica Complementaria 1 B 2
# Error R1: Salon: 4 Curso a comparar: ipc2 D 5 . Salon:5 Curso con el que se comparo:ipc2 D 5
# Error R1: Salon: 4 Curso a comparar: Matematica basica 1 A 1 . Salon:5 Curso con el que se comparo:Inteligencia Artificial A 1
# Error R2: Salon: 4 Curso a comparar: Matematica basica 1 A 1 . Curso con el que se comparo:Matematica basica 1 A 1
# Error R1: Salon: 4 Curso a comparar: Tecnica Complementaria 1 B 2 . Salon:1 Curso con el que se comparo:Fisica basica B 2
# Error R1: Salon: 4 Curso a comparar: Matematica basica 1 A 1 . Salon:2 Curso con el que se comparo:Inteligencia Artificial A 1
# Error R2: Salon: 4 Curso a comparar: Matematica basica 1 A 1 . Curso con el que se comparo:Matematica basica 1 A 1
# Error R1: Salon: 4 Curso a comparar: Compiladores 1 D 1 . Salon:2 Curso con el que se comparo:Compiladores 1 D 1
# ...
# Error R1: Salon: 5 Curso a comparar: Matemática Computo 1 A 3 . Salon:6 Curso con el que se comparo:Matemática Computo 1 A 3
# Error R1: Salon: 5 Curso a comparar: IPC1 A 3 . Salon:4 Curso con el que se comparo:Matemática Computo 1 A 3
# Error R1: Salon: 5 Curso a comparar: IPC1 A 3 . Salon:6 Curso con el que se comparo:Matemática Computo 1 A 3
# Error R1: Salon: 6 Curso a comparar: Matemática Aplicada 3 B 7 . Salon:4 Curso con el que se comparo:Matemática Aplicada 3 B 7
# Error R2: Salon: 6 Curso a comparar: Matemática Aplicada 3 B 7 . Curso con el que se comparo:Matemática Aplicada 3 B 7
# Error R1: Salon: 6 Curso a comparar: Teoria de Sistemas 1 B 6 . Salon:3 Curso con el que se comparo:Compiladores 2 B 6
# Error R2: Salon: 6 Curso a comparar: Matemática Aplicada 3 B 7 . Curso con el que se comparo:Matemática Aplicada 3 B 7
# Error R1: Salon: 6 Curso a comparar: Matemática Computo 1 A 3 . Salon:3 Curso con el que se comparo:IPC1 A 3
# Error R1: Salon: 6 Curso a comparar: Matemática Computo 1 A 3 . Salon:5 Curso con el que se comparo:Matemática Computo 1 A 3
# Error R2: Salon: 6 Curso a comparar: Matemática Computo 1 A 3 . Curso con el que se comparo:Matemática Computo 1 A 3
# Error R1: Salon: 6 Curso a comparar: Matemática Computo 1 A 3 . Salon:4 Curso con el que se comparo:Matemática Computo 1 A 3
# Error R1: Salon: 6 Curso a comparar: Matemática Computo 1 A 3 . Salon:5 Curso con el que se comparo:IPC1 A 3
# Error R2: Salon: 6 Curso a comparar: Matemática Computo 1 A 3 . Curso con el que se comparo:Matemática Computo 1 A 3
# Error R1: Salon: 6 Curso a comparar: ipc2 D 5 . Salon:2 Curso con el que se comparo:ipc2 D 5
# *****CROMSOMA 95****************
# Error R1: Salon: 1 Curso a comparar: Teoria de Sistemas 1 B 6 . Salon:4 Curso con el que se comparo:Compiladores 2 B 6
# Error R2: Salon: 1 Curso a comparar: lenguajes E 4 . Curso con el que se comparo:lenguajes E 4
# Error R2: Salon: 1 Curso a comparar: lenguajes E 4 . Curso con el que se comparo:lenguajes E 4
# Error R2: Salon: 3 Curso a comparar: IPC1 A 3 . Curso con el que se comparo:IPC1 A 3
# Error R1: Salon: 3 Curso a comparar: IPC1 A 3 . Salon:5 Curso con el que se comparo:Matemática Computo 1 A 3
# Error R2: Salon: 3 Curso a comparar: IPC1 A 3 . Curso con el que se comparo:IPC1 A 3
# Error R2: Salon: 3 Curso a comparar: Fisica basica B 2 . Curso con el que se comparo:Fisica basica B 2
# Error R2: Salon: 3 Curso a comparar: Fisica basica B 2 . Curso con el que se comparo:Fisica basica B 2
# Error R1: Salon: 4 Curso a comparar: Compiladores 2 B 6 . Salon:1 Curso con el que se comparo:Teoria de Sistemas 1 B 6
# Error R2: Salon: 4 Curso a comparar: Compiladores 2 B 6 . Curso con el que se comparo:Compiladores 2 B 6
# Error R2: Salon: 4 Curso a comparar: Compiladores 2 B 6 . Curso con el que se comparo:Compiladores 2 B 6
# Error R1: Salon: 4 Curso a comparar: Matemática Computo 1 A 3 . Salon:5 Curso con el que se comparo:Matemática Computo 1 A 3
# Error R1: Salon: 5 Curso a comparar: Matemática Computo 1 A 3 . Salon:3 Curso con el que se comparo:IPC1 A 3
# Error R2: Salon: 5 Curso a comparar: Matemática Computo 1 A 3 . Curso con el que se comparo:Matemática Computo 1 A 3
# Error R1: Salon: 5 Curso a comparar: Matemática Computo 1 A 3 . Salon:4 Curso con el que se comparo:Matemática Computo 1 A 3
# Error R2: Salon: 5 Curso a comparar: Matemática Computo 1 A 3 . Curso con el que se comparo:Matemática Computo 1 A 3
# Error R2: Salon: 6 Curso a comparar: Inteligencia Artificial A 9 . Curso con el que se comparo:Inteligencia Artificial A 9
# Error R2: Salon: 6 Curso a comparar: Inteligencia Artificial A 9 . Curso con el que se comparo:Inteligencia Artificial A 9
# *****CROMSOMA 96****************
# Error R2: Salon: 1 Curso a comparar: Compiladores 2 B 6 . Curso con el que se comparo:Compiladores 2 B 6
# Error R1: Salon: 1 Curso a comparar: Inteligencia Artificial A 1 . Salon:2 Curso con el que se comparo:Matematica basica 1 A 1
# Error R1: Salon: 1 Curso a comparar: Inteligencia Artificial A 1 . Salon:3 Curso con el que se comparo:Matematica basica 1 A 1
# Error R1: Salon: 1 Curso a comparar: Compiladores 2 B 6 . Salon:6 Curso con el que se comparo:Compiladores 2 B 6
# Error R2: Salon: 1 Curso a comparar: Compiladores 2 B 6 . Curso con el que se comparo:Compiladores 2 B 6
# Error R1: Salon: 2 Curso a comparar: Matematica basica 1 A 1 . Salon:1 Curso con el que se comparo:Inteligencia Artificial A 1
# Error R1: Salon: 2 Curso a comparar: Matematica basica 1 A 1 . Salon:3 Curso con el que se comparo:Matematica basica 1 A 1
# Error R1: Salon: 3 Curso a comparar: Matemática Computo 1 A 3 . Salon:4 Curso con el que se comparo:IPC1 A 3
# Error R1: Salon: 3 Curso a comparar: Matematica basica 1 A 1 . Salon:1 Curso con el que se comparo:Inteligencia Artificial A 1
# Error R1: Salon: 3 Curso a comparar: Matematica basica 1 A 1 . Salon:2 Curso con el que se comparo:Matematica basica 1 A 1
# Error R2: Salon: 3 Curso a comparar: Matematica basica 1 A 1 . Curso con el que se comparo:Matematica basica 1 A 1
# Error R1: Salon: 3 Curso a comparar: Inteligencia Artificial A 9 . Salon:5 Curso con el que se comparo:Inteligencia Artificial A 9
# Error R2: Salon: 3 Curso a comparar: Matematica basica 1 A 1 . Curso con el que se comparo:Matematica basica 1 A 1
# Error R1: Salon: 3 Curso a comparar: IPC1 A 3 . Salon:4 Curso con el que se comparo:Matemática Computo 1 A 3
# Error R1: Salon: 3 Curso a comparar: IPC1 A 3 . Salon:5 Curso con el que se comparo:Matemática Computo 1 A 3
# Error R1: Salon: 4 Curso a comparar: IPC1 A 3 . Salon:3 Curso con el que se comparo:Matemática Computo 1 A 3
# Error R1: Salon: 4 Curso a comparar: Matematica basica 1 A 1 . Salon:5 Curso con el que se comparo:Matematica basica 1 A 1
# Error R2: Salon: 4 Curso a comparar: Matemática Computo 1 A 3 . Curso con el que se comparo:Matemática Computo 1 A 3
# Error R2: Salon: 4 Curso a comparar: Matemática Computo 1 A 3 . Curso con el que se comparo:Matemática Computo 1 A 3
# Error R2: Salon: 4 Curso a comparar: Matemática Computo 1 A 3 . Curso con el que se comparo:Matemática Computo 1 A 3
# Error R2: Salon: 4 Curso a comparar: Matemática Computo 1 A 3 . Curso con el que se comparo:Matemática Computo 1 A 3
# Error R1: Salon: 4 Curso a comparar: Matemática Computo 1 A 3 . Salon:3 Curso con el que se comparo:IPC1 A 3
# Error R1: Salon: 4 Curso a comparar: Matemática Computo 1 A 3 . Salon:5 Curso con el que se comparo:Matemática Computo 1 A 3
# Error R2: Salon: 4 Curso a comparar: Matemática Computo 1 A 3 . Curso con el que se comparo:Matemática Computo 1 A 3
# Error R2: Salon: 4 Curso a comparar: Matemática Computo 1 A 3 . Curso con el que se comparo:Matemática Computo 1 A 3
# Error R1: Salon: 5 Curso a comparar: Matematica basica 1 A 1 . Salon:4 Curso con el que se comparo:Matematica basica 1 A 1
# Error R1: Salon: 5 Curso a comparar: Inteligencia Artificial A 9 . Salon:3 Curso con el que se comparo:Inteligencia Artificial A 9
# Error R1: Salon: 5 Curso a comparar: Matemática Computo 1 A 3 . Salon:3 Curso con el que se comparo:IPC1 A 3
# Error R1: Salon: 5 Curso a comparar: Matemática Computo 1 A 3 . Salon:4 Curso con el que se comparo:Matemática Computo 1 A 3
# Error R2: Salon: 6 Curso a comparar: ipc2 D 5 . Curso con el que se comparo:ipc2 D 5
# Error R1: Salon: 6 Curso a comparar: Compiladores 2 B 6 . Salon:1 Curso con el que se comparo:Compiladores 2 B 6
# Error R2: Salon: 6 Curso a comparar: ipc2 D 5 . Curso con el que se comparo:ipc2 D 5
# *****CROMSOMA 97****************
# Error R1: Salon: 1 Curso a comparar: Compiladores 1 D 1 . Salon:6 Curso con el que se comparo:Compiladores 1 D 1
# Error R1: Salon: 1 Curso a comparar: Matematica basica 1 A 1 . Salon:3 Curso con el que se comparo:Matematica basica 1 A 1
# Error R1: Salon: 2 Curso a comparar: Inteligencia Artificial A 1 . Salon:3 Curso con el que se comparo:Inteligencia Artificial A 1
# Error R1: Salon: 2 Curso a comparar: Inteligencia Artificial A 1 . Salon:4 Curso con el que se comparo:Matematica basica 1 A 1
# Error R1: Salon: 3 Curso a comparar: Matemática Aplicada 3 B 7 . Salon:6 Curso con el que se comparo:Matemática Aplicada 3 B 7
# Error R1: Salon: 3 Curso a comparar: Inteligencia Artificial A 1 . Salon:2 Curso con el que se comparo:Inteligencia Artificial A 1
# Error R1: Salon: 3 Curso a comparar: Inteligencia Artificial A 1 . Salon:4 Curso con el que se comparo:Matematica basica 1 A 1
# Error R2: Salon: 3 Curso a comparar: Matematica basica 1 A 1 . Curso con el que se comparo:Matematica basica 1 A 1
# Error R1: Salon: 3 Curso a comparar: Matematica basica 1 A 1 . Salon:1 Curso con el que se comparo:Matematica basica 1 A 1
# Error R2: Salon: 3 Curso a comparar: Matematica basica 1 A 1 . Curso con el que se comparo:Matematica basica 1 A 1
# Error R1: Salon: 4 Curso a comparar: Fisica basica B 2 . Salon:5 Curso con el que se comparo:Tecnica Complementaria 1 B 2
# Error R1: Salon: 4 Curso a comparar: Matematica basica 1 A 1 . Salon:2 Curso con el que se comparo:Inteligencia Artificial A 1
# Error R1: Salon: 4 Curso a comparar: Matematica basica 1 A 1 . Salon:3 Curso con el que se comparo:Inteligencia Artificial A 1
# Error R1: Salon: 5 Curso a comparar: Tecnica Complementaria 1 B 2 . Salon:4 Curso con el que se comparo:Fisica basica B 2
# Error R1: Salon: 5 Curso a comparar: ipc2 D 5 . Salon:6 Curso con el que se comparo:ipc2 D 5
# Error R2: Salon: 5 Curso a comparar: ipc2 D 5 . Curso con el que se comparo:ipc2 D 5
# Error R2: Salon: 5 Curso a comparar: ipc2 D 5 . Curso con el que se comparo:ipc2 D 5
# Error R1: Salon: 5 Curso a comparar: so1 C 6 . Salon:6 Curso con el que se comparo:so1 C 6
# Error R1: Salon: 6 Curso a comparar: Matemática Aplicada 3 B 7 . Salon:3 Curso con el que se comparo:Matemática Aplicada 3 B 7
# Error R2: Salon: 6 Curso a comparar: Matemática Aplicada 3 B 7 . Curso con el que se comparo:Matemática Aplicada 3 B 7
# Error R1: Salon: 6 Curso a comparar: ipc2 D 5 . Salon:5 Curso con el que se comparo:ipc2 D 5
# Error R2: Salon: 6 Curso a comparar: ipc2 D 5 . Curso con el que se comparo:ipc2 D 5
# Error R2: Salon: 6 Curso a comparar: Matemática Aplicada 3 B 7 . Curso con el que se comparo:Matemática Aplicada 3 B 7
# Error R1: Salon: 6 Curso a comparar: Compiladores 1 D 1 . Salon:1 Curso con el que se comparo:Compiladores 1 D 1
# Error R2: Salon: 6 Curso a comparar: ipc2 D 5 . Curso con el que se comparo:ipc2 D 5
# Error R1: Salon: 6 Curso a comparar: so1 C 6 . Salon:5 Curso con el que se comparo:so1 C 6
# *****CROMSOMA 98****************
# Error R1: Salon: 1 Curso a comparar: Matemática Aplicada 1 A 8 . Salon:4 Curso con el que se comparo:Matemática Aplicada 1 A 8
# Error R2: Salon: 1 Curso a comparar: lenguajes E 4 . Curso con el que se comparo:lenguajes E 4
# Error R2: Salon: 1 Curso a comparar: lenguajes E 4 . Curso con el que se comparo:lenguajes E 4
# Error R1: Salon: 1 Curso a comparar: Inteligencia Artificial A 9 . Salon:5 Curso con el que se comparo:Inteligencia Artificial A 9
# Error R1: Salon: 2 Curso a comparar: Compiladores 1 D 1 . Salon:5 Curso con el que se comparo:Compiladores 1 D 1
# Error R1: Salon: 2 Curso a comparar: Tecnica Complementaria 1 B 2 . Salon:4 Curso con el que se comparo:Fisica basica B 2
# Error R1: Salon: 2 Curso a comparar: Compiladores 2 B 6 . Salon:4 Curso con el que se comparo:Teoria de Sistemas 1 B 6
# Error R2: Salon: 3 Curso a comparar: ipc1 C 4 . Curso con el que se comparo:ipc1 C 4
# Error R1: Salon: 3 Curso a comparar: Teoria de Sistemas 1 B 6 . Salon:4 Curso con el que se comparo:Compiladores 2 B 6
# Error R1: Salon: 3 Curso a comparar: Teoria de Sistemas 1 B 6 . Salon:5 Curso con el que se comparo:Compiladores 2 B 6
# Error R2: Salon: 3 Curso a comparar: ipc1 C 4 . Curso con el que se comparo:ipc1 C 4
# Error R1: Salon: 4 Curso a comparar: Matemática Aplicada 1 A 8 . Salon:1 Curso con el que se comparo:Matemática Aplicada 1 A 8
# Error R1: Salon: 4 Curso a comparar: Fisica basica B 2 . Salon:2 Curso con el que se comparo:Tecnica Complementaria 1 B 2
# Error R1: Salon: 4 Curso a comparar: Teoria de Sistemas 1 B 6 . Salon:2 Curso con el que se comparo:Compiladores 2 B 6
# Error R1: Salon: 4 Curso a comparar: Compiladores 2 B 6 . Salon:3 Curso con el que se comparo:Teoria de Sistemas 1 B 6
# Error R1: Salon: 4 Curso a comparar: Compiladores 2 B 6 . Salon:5 Curso con el que se comparo:Compiladores 2 B 6
# Error R1: Salon: 5 Curso a comparar: Compiladores 1 D 1 . Salon:2 Curso con el que se comparo:Compiladores 1 D 1
# Error R1: Salon: 5 Curso a comparar: Teoria de Sistemas 1 B 6 . Salon:6 Curso con el que se comparo:Teoria de Sistemas 1 B 6
# Error R1: Salon: 5 Curso a comparar: ipc1 C 4 . Salon:6 Curso con el que se comparo:ipc1 C 4
# Error R1: Salon: 5 Curso a comparar: Compiladores 2 B 6 . Salon:3 Curso con el que se comparo:Teoria de Sistemas 1 B 6
# Error R1: Salon: 5 Curso a comparar: Compiladores 2 B 6 . Salon:4 Curso con el que se comparo:Compiladores 2 B 6
# Error R1: Salon: 5 Curso a comparar: Inteligencia Artificial A 9 . Salon:1 Curso con el que se comparo:Inteligencia Artificial A 9
# Error R1: Salon: 6 Curso a comparar: Teoria de Sistemas 1 B 6 . Salon:5 Curso con el que se comparo:Teoria de Sistemas 1 B 6
# Error R2: Salon: 6 Curso a comparar: Teoria de Sistemas 1 B 6 . Curso con el que se comparo:Teoria de Sistemas 1 B 6
# Error R1: Salon: 6 Curso a comparar: ipc1 C 4 . Salon:5 Curso con el que se comparo:ipc1 C 4
# Error R2: Salon: 6 Curso a comparar: ipc1 C 4 . Curso con el que se comparo:ipc1 C 4
# Error R2: Salon: 6 Curso a comparar: ipc1 C 4 . Curso con el que se comparo:ipc1 C 4
# Error R2: Salon: 6 Curso a comparar: Teoria de Sistemas 1 B 6 . Curso con el que se comparo:Teoria de Sistemas 1 B 6
# *****CROMSOMA 99****************
# Error R2: Salon: 1 Curso a comparar: Matematica basica 1 A 1 . Curso con el que se comparo:Matematica basica 1 A 1
# Error R2: Salon: 1 Curso a comparar: Matematica basica 1 A 1 . Curso con el que se comparo:Matematica basica 1 A 1
# Error R2: Salon: 1 Curso a comparar: ipc2 D 5 . Curso con el que se comparo:ipc2 D 5
# Error R1: Salon: 1 Curso a comparar: ipc2 D 5 . Salon:3 Curso con el que se comparo:ipc2 D 5
# Error R2: Salon: 1 Curso a comparar: ipc2 D 5 . Curso con el que se comparo:ipc2 D 5
# Error R1: Salon: 2 Curso a comparar: Teoria de Sistemas 1 B 6 . Salon:5 Curso con el que se comparo:Teoria de Sistemas 1 B 6
# Error R1: Salon: 2 Curso a comparar: Inteligencia Artificial A 1 . Salon:6 Curso con el que se comparo:Matematica basica 1 A 1
# Error R1: Salon: 3 Curso a comparar: Compiladores 1 D 1 . Salon:4 Curso con el que se comparo:Compiladores 1 D 1
# Error R2: Salon: 3 Curso a comparar: Compiladores 1 D 1 . Curso con el que se comparo:Compiladores 1 D 1
# Error R1: Salon: 3 Curso a comparar: Matemática Aplicada 1 A 8 . Salon:4 Curso con el que se comparo:Matemática Aplicada 1 A 8
# Error R1: Salon: 3 Curso a comparar: ipc2 D 5 . Salon:1 Curso con el que se comparo:ipc2 D 5
# Error R1: Salon: 3 Curso a comparar: Compiladores 1 D 1 . Salon:4 Curso con el que se comparo:Compiladores 1 D 1
# Error R2: Salon: 3 Curso a comparar: Compiladores 1 D 1 . Curso con el que se comparo:Compiladores 1 D 1
# Error R1: Salon: 4 Curso a comparar: Compiladores 1 D 1 . Salon:3 Curso con el que se comparo:Compiladores 1 D 1
# Error R2: Salon: 4 Curso a comparar: Compiladores 1 D 1 . Curso con el que se comparo:Compiladores 1 D 1
# Error R1: Salon: 4 Curso a comparar: Matemática Aplicada 1 A 8 . Salon:3 Curso con el que se comparo:Matemática Aplicada 1 A 8
# Error R1: Salon: 4 Curso a comparar: Compiladores 1 D 1 . Salon:3 Curso con el que se comparo:Compiladores 1 D 1
# Error R2: Salon: 4 Curso a comparar: Compiladores 1 D 1 . Curso con el que se comparo:Compiladores 1 D 1
# Error R2: Salon: 5 Curso a comparar: Compiladores 2 B 6 . Curso con el que se comparo:Compiladores 2 B 6
# Error R1: Salon: 5 Curso a comparar: Teoria de Sistemas 1 B 6 . Salon:2 Curso con el que se comparo:Teoria de Sistemas 1 B 6
# Error R2: Salon: 5 Curso a comparar: Compiladores 2 B 6 . Curso con el que se comparo:Compiladores 2 B 6
# Error R1: Salon: 6 Curso a comparar: Matematica basica 1 A 1 . Salon:2 Curso con el que se comparo:Inteligencia Artificial A 1

# %%
from flask_ngrok import run_with_ngrok
from flask import Flask
from flask import jsonify
import json

app = Flask(__name__)
run_with_ngrok(app)

@app.route('/')
def helloWorld():
  return 'Hello,World'

def crearJsonListCurso(listadoDeCursos):
  cursos ={}
  cursos['curso']=[]
  for curso in listadoDeCursos:
      curso ={
          'codigo':curso.codigo,
          'nombre':curso.nombre,
          'ciclo':curso.ciclo,
          'seccion':curso.seccion,
          'carrera':curso.carrera
      }
      cursos['curso'].append(curso)
  return cursos

def crearJsonList(listadoDeSalones):
  salones = {}
  salones['salon'] =[]
#  salones['numeroDeSalon']=[]
  numeroDeSalon=1;
  for salon in listadoDeSalones:
#    salones['numeroDeSalon'].append(numeroDeSalon)
    salones['salon'].append({
        'numeroDeSalon':numeroDeSalon,
        'cursos':crearJsonListCurso(salon)        
    })
    numeroDeSalon+=1
  return salones


@app.route('/poblacion')
def getPoblacion():
  cromosomas = {}
  #cromosomas['porcentaje']=[]
  #cromosomas['salones']=[]
  cromosomas['cromosoma'] = []
  for crom in poblacionInicial:

    #Ya funciono 
    #cromosomas['porcentaje'].append({'porcentaje':crom.porcentaje})
    #cromosomas['salones'].append(crearJsonList(crom.lista))
    cromosomas['cromosoma'].append({
          'salones' : crearJsonList(crom.lista),
          'porcentaje' : crom.porcentaje
       })

  return cromosomas


if __name__ == '__main__':
  app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
#  * Running on http://e7e3072c6b49.ngrok.io
#  * Traffic stats available on http://127.0.0.1:4040
# 127.0.0.1 - - [29/Apr/2021 09:56:54] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2021 09:56:54] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [29/Apr/2021 09:56:58] "GET /poblacion HTTP/1.1" 200 -
